# %%
# %pip install arm-pyart s3fs
# Out:
# Requirement already satisfied: arm-pyart in /opt/anaconda3/lib/python3.13/site-packages (2.2.4)
# Requirement already satisfied: s3fs in /opt/anaconda3/lib/python3.13/site-packages (2025.10.0)
# Requirement already satisfied: cartopy>=0.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (0.25.0)
# Requirement already satisfied: cftime>=1.5.2 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (1.6.5)
# Requirement already satisfied: fsspec>=2021.11.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (2025.10.0)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (3.10.6)
# Requirement already satisfied: mda-xdrlib>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (0.2.0)
# Requirement already satisfied: netcdf4>=1.7.2 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (1.7.4)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (2.3.5)
# Requirement already satisfied: open-radar-data>=0.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (0.8.0)
# Requirement already satisfied: pandas>=1.3.4 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (2.3.3)
# Requirement already satisfied: pint>=0.18.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (0.25.3)
# Requirement already satisfied: pooch>=1.5.2 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (1.9.0)
# Requirement already satisfied: scipy>=1.7.3 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (1.16.3)
# Requirement already satisfied: xarray>=2024.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (2026.4.0)
# Requirement already satisfied: xradar>=0.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from arm-pyart) (0.12.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/anaconda3/lib/python3.13/site-packages (from s3fs) (2.25.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.13/site-packages (from s3fs) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: botocore<1.40.50,>=1.40.46 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.40.46)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.22.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/anaconda3/lib/python3.13/site-packages (from botocore<1.40.50,>=1.40.46->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.11)
# Requirement already satisfied: shapely>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.22.0->arm-pyart) (2.1.2)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.22.0->arm-pyart) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.22.0->arm-pyart) (3.0.13)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.22.0->arm-pyart) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.5.0->arm-pyart) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.5.0->arm-pyart) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.5.0->arm-pyart) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.5.0->arm-pyart) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.5.0->arm-pyart) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.5.0->arm-pyart) (3.2.5)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from netcdf4>=1.7.2->arm-pyart) (2025.11.12)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.4->arm-pyart) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.4->arm-pyart) (2025.2)
# Requirement already satisfied: flexcache>=0.3 in /opt/anaconda3/lib/python3.13/site-packages (from pint>=0.18.0->arm-pyart) (0.3)
# Requirement already satisfied: flexparser>=0.4 in /opt/anaconda3/lib/python3.13/site-packages (from pint>=0.18.0->arm-pyart) (0.4)
# Requirement already satisfied: platformdirs>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from pint>=0.18.0->arm-pyart) (4.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pint>=0.18.0->arm-pyart) (4.15.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from pooch>=1.5.2->arm-pyart) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5.2->arm-pyart) (3.4.4)
# Requirement already satisfied: cmweather in /opt/anaconda3/lib/python3.13/site-packages (from xradar>=0.12.0->arm-pyart) (0.3.2)
# Requirement already satisfied: dask in /opt/anaconda3/lib/python3.13/site-packages (from xradar>=0.12.0->arm-pyart) (2025.11.0)
# Requirement already satisfied: h5netcdf>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from xradar>=0.12.0->arm-pyart) (1.8.1)
# Requirement already satisfied: h5py>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from xradar>=0.12.0->arm-pyart) (3.15.1)
# Requirement already satisfied: lat_lon_parser in /opt/anaconda3/lib/python3.13/site-packages (from xradar>=0.12.0->arm-pyart) (1.3.1)
# Requirement already satisfied: xmltodict in /opt/anaconda3/lib/python3.13/site-packages (from xradar>=0.12.0->arm-pyart) (1.0.4)
# Requirement already satisfied: click>=8.1 in /opt/anaconda3/lib/python3.13/site-packages (from dask->xradar>=0.12.0->arm-pyart) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask->xradar>=0.12.0->arm-pyart) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask->xradar>=0.12.0->arm-pyart) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from dask->xradar>=0.12.0->arm-pyart) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask->xradar>=0.12.0->arm-pyart) (1.0.0)
# Requirement already satisfied: locket in /opt/anaconda3/lib/python3.13/site-packages (from partd>=1.4.0->dask->xradar>=0.12.0->arm-pyart) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gzip, io
import fsspec, pyart
import matplotlib.pyplot as plt

# --- 1. connect to the public NEXRAD archive (anonymous) ---
fs = fsspec.filesystem("s3", anon=True)
folder = "unidata-nexrad-level2/2006/03/11/KNKX/"

# --- 2. (optional) browse the folder to pick a ~05 UTC volume ---
for f in fs.ls(folder):
    print(f.split("/")[-1])
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly supported
# ## by the U.S. Department of Energy Office of Science as part of
# ## the Atmospheric Radiation Measurement (ARM) User Facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
# KNKX20060311_000025.gz
# KNKX20060311_000544.gz
# KNKX20060311_001001.gz
# KNKX20060311_001418.gz
# KNKX20060311_001835.gz
# KNKX20060311_002252.gz
# KNKX20060311_002709.gz
# KNKX20060311_003126.gz
# KNKX20060311_003544.gz
# KNKX20060311_004000.gz
# KNKX20060311_004417.gz
# KNKX20060311_004835.gz
# KNKX20060311_005251.gz
# KNKX20060311_005708.gz
# KNKX20060311_010126.gz
# KNKX20060311_010543.gz
# KNKX20060311_011000.gz
# KNKX20060311_011417.gz
# KNKX20060311_011834.gz
# KNKX20060311_012251.gz
# KNKX20060311_012709.gz
# KNKX20060311_152811.gz
# KNKX20060311_153229.gz
# KNKX20060311_153645.gz
# KNKX20060311_154102.gz
# KNKX20060311_154520.gz
# KNKX20060311_154936.gz
# KNKX20060311_155354.gz
# KNKX20060311_155811.gz
# KNKX20060311_160228.gz
# KNKX20060311_160645.gz
# KNKX20060311_161209.gz
# KNKX20060311_161626.gz
# KNKX20060311_162044.gz
# KNKX20060311_162501.gz
# KNKX20060311_162918.gz
# KNKX20060311_163336.gz
# KNKX20060311_163753.gz
# KNKX20060311_164210.gz
# KNKX20060311_164627.gz
# KNKX20060311_165044.gz
# KNKX20060311_165501.gz
# KNKX20060311_165918.gz
# KNKX20060311_170336.gz
# KNKX20060311_170753.gz
# KNKX20060311_171210.gz
# KNKX20060311_171627.gz
# KNKX20060311_172044.gz
# KNKX20060311_172502.gz
# KNKX20060311_172919.gz
# KNKX20060311_173336.gz
# KNKX20060311_173754.gz
# KNKX20060311_174210.gz
# KNKX20060311_174628.gz
# KNKX20060311_175045.gz
# KNKX20060311_175502.gz
# KNKX20060311_175919.gz
# KNKX20060311_180337.gz
# KNKX20060311_180754.gz
# KNKX20060311_181211.gz
# KNKX20060311_181628.gz
# KNKX20060311_182046.gz
# KNKX20060311_182503.gz
# KNKX20060311_182920.gz
# KNKX20060311_183338.gz
# KNKX20060311_183755.gz
# KNKX20060311_184212.gz
# KNKX20060311_184630.gz
# KNKX20060311_185047.gz
# KNKX20060311_185504.gz
# KNKX20060311_185922.gz
# KNKX20060311_190339.gz
# KNKX20060311_190756.gz
# KNKX20060311_191213.gz
# KNKX20060311_191630.gz
# KNKX20060311_192048.gz
# KNKX20060311_192505.gz
# KNKX20060311_192922.gz
# KNKX20060311_193339.gz
# KNKX20060311_193757.gz
# KNKX20060311_194214.gz
# KNKX20060311_194631.gz
# KNKX20060311_195048.gz
# KNKX20060311_195505.gz
# KNKX20060311_195922.gz
# KNKX20060311_200339.gz
# KNKX20060311_200756.gz
# KNKX20060311_201214.gz
# KNKX20060311_201631.gz
# KNKX20060311_202048.gz
# KNKX20060311_202505.gz
# KNKX20060311_202923.gz
# KNKX20060311_203340.gz
# KNKX20060311_203756.gz
# KNKX20060311_204214.gz
# KNKX20060311_204631.gz
# KNKX20060311_205048.gz
# KNKX20060311_205505.gz
# KNKX20060311_205922.gz
# KNKX20060311_210340.gz
# KNKX20060311_210757.gz
# KNKX20060311_211215.gz
# KNKX20060311_211632.gz
# KNKX20060311_212049.gz
# KNKX20060311_212506.gz
# KNKX20060311_212923.gz
# KNKX20060311_213340.gz
# KNKX20060311_213757.gz
# KNKX20060311_214214.gz
# KNKX20060311_214631.gz
# KNKX20060311_215049.gz
# KNKX20060311_215506.gz
# KNKX20060311_215923.gz
# KNKX20060311_220339.gz
# KNKX20060311_220757.gz
# KNKX20060311_221215.gz
# KNKX20060311_221632.gz
# KNKX20060311_222049.gz
# KNKX20060311_222506.gz
# KNKX20060311_222923.gz
# KNKX20060311_223341.gz
# KNKX20060311_223758.gz
# KNKX20060311_224215.gz
# KNKX20060311_224632.gz
# KNKX20060311_225049.gz
# KNKX20060311_225506.gz
# KNKX20060311_225924.gz
# KNKX20060311_230341.gz
# KNKX20060311_230758.gz
# KNKX20060311_231215.gz
# KNKX20060311_231632.gz
# KNKX20060311_232049.gz
# KNKX20060311_232507.gz
# KNKX20060311_232924.gz
# KNKX20060311_233341.gz
# KNKX20060311_233758.gz
# KNKX20060311_234216.gz
# KNKX20060311_234632.gz
# KNKX20060311_235050.gz
# KNKX20060311_235507.gz
# KNKX20060311_235924.gz

# %%
import numpy as np

# --- read radar ---
key = folder + "KNKX20060311_222506.gz"

with fs.open(key, "rb") as fh:
    raw = fh.read()

if raw[:2] == b"\x1f\x8b":
    raw = gzip.decompress(raw)

radar = pyart.io.read_nexrad_archive(io.BytesIO(raw))

# %%
print(radar.fixed_angle["data"])
# Out:
# [ 0.5  0.4  0.8  0.8  1.4  1.2  1.7  2.3  3.   3.9  5.1  6.2  7.8  9.8
#  12.3 15.5 19.4]

# %%
product = "reflectivity"
#product = "velocity"

# %%
# --- figure setup (more compact) ---
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
axes = axes.ravel()

disp = pyart.graph.RadarDisplay(radar)
max_range = 50

if product == "reflectivity":
  sweeps = 0, 4, 8, 10
else:
  sweeps = 1, 5, 8, 10

for i in range(4):
    ax = axes[i]
    plt.sca(ax)

    if product == "reflectivity":
        disp.plot_ppi(
            product,
            sweep=sweeps[i],
            vmin=-20,
            vmax=75,
            cmap="NWSRef",
            colorbar_flag=False
        )
    else:
        disp.plot_ppi(
            product,
            sweep=sweeps[i],
            vmin=-35,
            vmax=35,
            cmap="NWSVel",
            colorbar_flag=False
        )

    disp.set_limits(xlim=(-max_range, max_range),
                    ylim=(-max_range, max_range))

    # range rings
    disp.plot_range_rings(
        [50, 100, 150, 200, 250, 300, 350, 400],
        col="gray", lw=0.5, ls="dotted"
    )

    # azimuth spokes
    for az in range(0, 360, 30):
        theta = np.deg2rad(az)
        x = [0, max_range * np.sin(theta)]
        y = [0, max_range * np.cos(theta)]
        ax.plot(x, y, color="gray", lw=0.5, ls="dashed")

    # title
    angle = radar.fixed_angle["data"][sweeps[i]]
    ax.set_title(f"{angle:.2f}°", fontsize=11)

# --- MANUAL spacing (prevents overlap) ---
plt.subplots_adjust(
    left=0.1, right=0.9,
    top=0.9, bottom=0.1,
    wspace=0.2, hspace=0.2
)

# --- dedicated colorbar axis (below plots) ---
cax = fig.add_axes([0.2, 0.01, 0.6, 0.01])  # [left, bottom, width, height]

cbar = plt.colorbar(disp.plots[0], cax=cax, orientation="horizontal")
if product == "reflectivity":
    cbar.set_label("Reflectivity (dBZ)")
else:
    cbar.set_label("Velocity (m/s)")


plt.savefig("image.png", dpi=80)
plt.show()
